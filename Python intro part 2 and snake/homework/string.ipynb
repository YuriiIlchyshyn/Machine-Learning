# %% [markdown]
#   ## [PYTHON](https://uk.wikipedia.org/wiki/%D0%9B%D0%B5%D1%82%D1%8E%D1%87%D0%B8%D0%B9_%D1%86%D0%B8%D1%80%D0%BA_%D0%9C%D0%BE%D0%BD%D1%82%D1%96_%D0%9F%D0%B0%D0%B9%D1%82%D0%BE%D0%BD%D0%B0) STRING
#   ![%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5.png](attachment:%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5.png)

# %% [markdown]
# ## Hello, my name is Fred

# %% [markdown]
# ### Можна використовувати 2 види лапок: одинарні і подвійні

# %%
print("Hello")
print('Hello')
# Out:
# Hello
# Hello

# %% [markdown]
# ### Створимо змінну типу string

# %%
fred = 'Що таке рожеве і пухнасте? Рожевий пухнастик!'
print(fred)
# Out:
# Що таке рожеве і пухнасте? Рожевий пухнастик!

# %%
fred = 'Що таке рожеве і пухнасте? %s пухнастик!'
pink = 'Рожевий'
print(fred%pink)
# Out:
# Що таке рожеве і пухнасте? Рожевий пухнастик!

# %% [markdown]
# ### Що робити, якщо ми хочемо ввести текст на кілька рядочків?

# %%
Magic = '''Wingardium 
Leviosa !!!!'''
print(Magic)
# Out:
# Wingardium
# Leviosa !!!!

# %%
Magic = """Lumos 
Solem!!
# !!"""
print(Magic)
# Out:
# Lumos
# Solem!!
# !!

# %% [markdown]
# ### [д'Артаньян](https://uk.wikipedia.org/wiki/%D0%94%27%D0%90%D1%80%D1%82%D0%B0%D0%BD%D1%8C%D1%8F%D0%BD) і його проблеми

# %%
charles = '"Щось тут не так"-подумав д'Артаньян'
print(charles)
# Out:
#   File "<ipython-input-29-ae1e367c1e87>", line 1
#     charles = '"Щось тут не так"-подумав д'Артаньян'
#                                                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Ми спробували написати цитату, та ще цікаве ім'я нашого героя

# %%
charles = '"Щось тут не так"-подумав д' # так працює
print(charles)
# Out:
# "Щось тут не так"-подумав д

# %% [markdown]
# ### А що коли записати в подвійних

# %%
charles = """Щось тут не так"-подумав д'Артаньян"
print(charles)
# Out:
#   File "<ipython-input-31-b48efc99e7ca>", line 2
#     print(charles)
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %% [markdown]
# ### Ганебна ситуація
# ### Тоді спробуємо зробити таке:

# %%
charles = '''"Щось тут не так"-подумав д'Артаньян'''
print(charles)
# Out:
# "Щось тут не так"-подумав д'Артаньян

# %% [markdown]
# ### Урааааа
# ### Є ще одне рішення за допомогою символа \

# %%
single_quote_str = '"Щось тут не так", — подумав д\'Артаньян'
double_quote_str = "\"Щось тут не так\", —  подумав д'Артаньян"
print(single_quote_str)
print(double_quote_str)
# Out:
# "Щось тут не так", — подумав д'Артаньян
# "Щось тут не так", —  подумав д'Артаньян

# %% [markdown]
# ### Повідомлення від Фреда

# %%
spaces = ' ' * 25
print('%s Зелена алея 12' % spaces)
print('%s Трясовинасіті' % spaces)
print('%s Лісокантрі' % spaces)
print()
print()
print('Вельмишановний сер,')
print()
print('Хочу повідомити вас, щось надзвичайно важливе, а саме:')
print('на даху не вистачає черепиці.')
print('Думаю, минулої ночі її нахабно викрав вітер.')
print()
print('З повагою')
print('Спостережлевий Фред')
# Out:
#                           Зелена алея 12
#                           Трясовинасіті
#                           Лісокантрі
#
#
# Вельмишановний сер,
#
# Хочу повідомити вас, щось надзвичайно важливе, а саме:
# на даху не вистачає черепиці.
# Думаю, минулої ночі її нахабно викрав вітер.
#
# З повагою
# Спостережлевий Фред

# %% [markdown]
# ### Ігри зі стрічками

# %%
s = "Hello, World!"
print(s[1])
print(s[2:5])
print(s[-5:-2])
# Out:
# e
# llo
# orl

# %%
a = "Hello, World!"
print(len(a))
# Out:
# 13

# %%
a = " Hello, World! " 
print(a.strip()) # returns "Hello, World!"
# Out:
# Hello, World!

# %%
# Магія CapsLk
a = "Hello, World!"
print(a.lower())
print(a.upper())
# Out:
# hello, world!
# HELLO, WORLD!

# %%
a = "Hello, World!"
print(a.replace("H", "J"))
# Out:
# Jello, World!

# %%
a = "Hello, World!"
print(a.split(",")) # returns ['Hello', ' World!']
# Out:
# ['Hello', ' World!']

# %%
txt = "The rain in Spain stays mainly in the plain"
x = "ain" in txt
print(x) 
z = "ain" not in txt
print(z)
# Out:
# True
# False

# %%
a = "Hello"
b = "World"
c = a + b
print(c)
c = a + " " + b
print(c)
# Out:
# HelloWorld
# Hello World

# %%
#A backslash followed by an 'x' and a hex number represents a hex value:
txt = "\x48\x65\x6c\x6c\x6f"
print(txt)
# Out:
# Hello

# %%
txt = "hello, and welcome to my world."
x = txt.capitalize()
print (x)
# Out:
# Hello, and welcome to my world.

# %%
#named indexes:
txt1 = "My name is {fname}, I'm {age}".format(fname = "John", age = 36)
#numbered indexes:
txt2 = "My name is {0}, I'm {1}".format("John",36)
#empty placeholders:
txt3 = "My name is {}, I'm {}".format("John",36)
print(txt1)
print(txt2)
print(txt3)
# Out:
# My name is John, I'm 36
# My name is John, I'm 36
# My name is John, I'm 36

# %%
txt = "Hello, welcome to my world."
x = txt.endswith(".")
print(x)
# Out:
# True
